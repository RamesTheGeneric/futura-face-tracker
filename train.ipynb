# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import sin, cos, pi
import cv2, os
from tqdm.auto import tqdm

import tensorflow
from tensorflow import keras 
# from keras.models import Sequential, Model, load_model
# Out:
# 2021-11-04 21:53:22.673720: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
class config:
    horizontal_flip = True
    rotation_augmentation = True
    brightness_augmentation = True
    shift_augmentation = True
    random_noise_augmentation = True

    rotation_angles = [12]    # Rotation angle in degrees (includes both clockwise & anti-clockwise rotations)
    pixel_shifts = [12]    # Horizontal & vertical shift amount in pixels (includes shift from all 4 corners)

    NUM_EPOCHS = 120
    BATCH_SIZE = 64
    X_RES = 128
    Y_RES = 128

# %% [markdown]
# # Loading Data

# %%
# print("Contents of input/facial-keypoints-detection directory: ")
# !ls ../input/facial-keypoints-detection/

# print("\nExtracting .zip dataset files to working directory ...")
# !unzip -u ../input/facial-keypoints-detection/test.zip
# !unzip -u ../input/facial-keypoints-detection/training.zip

# print("\nCurrent working directory:")
# !pwd
# print("\nContents of working directory:")
# !ls

# %%
# %%time

dataset_folder = './Dataset/'
model_file = dataset_folder + 'model_1634576239418.json'
test_file = dataset_folder + 'model_1634576239418.json'
train_data = pd.read_json(model_file, orient='columns')
test_data = pd.read_json(test_file, orient='columns')
# idlookup_data = pd.read_csv(idlookup_file)
# Out:
# CPU times: user 12.3 ms, sys: 2.54 ms, total: 14.9 ms
# Wall time: 16.6 ms

# %%
def plot_sample(image, keypoint, axis, title):
    # image = image.reshape(1920, 1080)
    axis.imshow(image, cmap='gray')
    axis.scatter(keypoint[0::2], keypoint[1::2], marker='x', s=20)
    plt.title(title)

# %% [markdown]
# ## Exploring Data

# %%
print("Length of train data:", len(train_data))
# Out:
# Length of train data: 83

# %% [markdown]
# **Find columns having Null values and their counts**

# %%
train_data.isnull().sum()
# Out:
# image     0
# points    0
# dtype: int64

# %% [markdown]
# #### We can observe that approx. 68% of data is missing for several keypoints

# %%
clean_train_data = train_data.dropna()
print("clean_train_data shape:", np.shape(clean_train_data))
# Out:
# clean_train_data shape: (83, 2)

# %%
# %%time



def load_images(image_data):
    images = []
    for index, row in image_data.iterrows():
        img = cv2.imread(dataset_folder + row['image'], cv2.IMREAD_GRAYSCALE) 
        # img = img.astype(np.uint8)
        # gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        img = cv2.resize(img, dsize=(config.X_RES, config.Y_RES))
        # img = img.astype(np.uint8)
        # _, binary = cv2.threshold(img, 255 // 2, 255, cv2.THRESH_BINARY_INV)
        # contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        # blank_image = np.ones((128,128,1), np.uint8)
        # img = cv2.drawContours(blank_image, contours, -1, (255,255,255), 1)
        img = np.reshape(img, (config.X_RES, config.Y_RES,1))
        # image = np.reshape(gray, (1920, 1080, 1))
        images.append(img)
    
    images = np.array(images)/255.
    return images

def load_keypoints(keypoint_data):
    keypoint_features = []

    keys = keypoint_data['points'].apply(lambda i: np.reshape(i, len(i) * 2))
    for idx, sample_keypoints in keys.items():
        keypoint_features.append(sample_keypoints)
    keypoint_features = np.array(keypoint_features, dtype = 'float')
    return keypoint_features

clean_train_images = load_images(clean_train_data)
print("Shape of clean_train_images:", np.shape(clean_train_images))
clean_train_keypoints = load_keypoints(clean_train_data)
print("Shape of clean_train_keypoints:", np.shape(clean_train_keypoints))
test_images = load_images(test_data)
print("Shape of test_images:", np.shape(test_images))

train_images = clean_train_images
train_keypoints = clean_train_keypoints
fig, axis = plt.subplots()
plot_sample(clean_train_images[19], clean_train_keypoints[19], axis, "Sample image & keypoints")
# Out:
# Shape of clean_train_images: (83, 128, 128, 1)
# Shape of clean_train_keypoints: (83, 16)
# Shape of test_images: (83, 128, 128, 1)
# CPU times: user 66.1 ms, sys: 10.9 ms, total: 77 ms
# Wall time: 84.8 ms

# %% [markdown]
# # Augmentation

# %%
def left_right_flip(images, keypoints):
    flipped_keypoints = []
    flipped_images = np.flip(images, axis=2)   # Flip column-wise (axis=2)
    for idx, sample_keypoints in enumerate(keypoints):
        flipped_keypoints.append([config.X_RES-coor if idx%2==0 else coor for idx,coor in enumerate(sample_keypoints)])    # Subtract only X co-ordinates of keypoints from 96 for horizontal flipping
    return flipped_images, flipped_keypoints

if config.horizontal_flip:
    flipped_train_images, flipped_train_keypoints = left_right_flip(clean_train_images, clean_train_keypoints)
    print("Shape of flipped_train_images:", np.shape(flipped_train_images))
    print("Shape of flipped_train_keypoints:", np.shape(flipped_train_keypoints))
    train_images = np.concatenate((train_images, flipped_train_images))
    train_keypoints = np.concatenate((train_keypoints, flipped_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(flipped_train_images[19], flipped_train_keypoints[19], axis, "Horizontally Flipped")
# Out:
# Shape of flipped_train_images: (83, 128, 128, 1)
# Shape of flipped_train_keypoints: (83, 16)

# %%
def rotate_augmentation(images, keypoints):
    rotated_images = []
    rotated_keypoints = []
    print("Augmenting for angles (in degrees): ")
    for angle in config.rotation_angles:    # Rotation augmentation for a list of angle values
        for angle in [angle,-angle]:
            print(f'{angle}', end='  ')
            M = cv2.getRotationMatrix2D((config.X_RES / 2,config.X_RES / 2), angle, 1.0)
            angle_rad = -angle*pi/180.     # Obtain angle in radians from angle in degrees (notice negative sign for change in clockwise vs anti-clockwise directions from conventional rotation to cv2's image rotation)
            # For train_images
            for image in images:
                rotated_image = cv2.warpAffine(image, M, (config.X_RES, config.Y_RES), flags=cv2.INTER_CUBIC)
                rotated_images.append(rotated_image)
            # For train_keypoints
            for keypoint in keypoints:
                rotated_keypoint = keypoint - config.X_RES / 2    # Subtract the middle value of the image dimension
                for idx in range(0,len(rotated_keypoint),2):
                    # https://in.mathworks.com/matlabcentral/answers/93554-how-can-i-rotate-a-set-of-points-in-a-plane-by-a-certain-angle-about-an-arbitrary-point
                    rotated_keypoint[idx] = rotated_keypoint[idx]*cos(angle_rad)-rotated_keypoint[idx+1]*sin(angle_rad)
                    rotated_keypoint[idx+1] = rotated_keypoint[idx]*sin(angle_rad)+rotated_keypoint[idx+1]*cos(angle_rad)
                rotated_keypoint += config.X_RES / 2   # Add the earlier subtracted value
                rotated_keypoints.append(rotated_keypoint)
            
    return np.reshape(rotated_images,(-1,config.X_RES,config.X_RES,1)), rotated_keypoints

print()

if config.rotation_augmentation:
    rotated_train_images, rotated_train_keypoints = rotate_augmentation(clean_train_images, clean_train_keypoints)
    print("Shape of rotated_train_images:", np.shape(rotated_train_images))
    print("Shape of rotated_train_keypoints:", np.shape(rotated_train_keypoints))
    train_images = np.concatenate((train_images, rotated_train_images))
    train_keypoints = np.concatenate((train_keypoints, rotated_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(rotated_train_images[19], rotated_train_keypoints[19], axis, "Rotation Augmentation")
# Out:
# Augmenting for angles (in degrees):
# 12  -12  Shape of rotated_train_images: (166, 128, 128, 1)
# Shape of rotated_train_keypoints: (166, 16)

# %%
def alter_brightness(images, keypoints):
    altered_brightness_images = []
    inc_brightness_images = np.clip(images*1.2, 0.0, 1.0)    # Increased brightness by a factor of 1.2 & clip any values outside the range of [-1,1]
    dec_brightness_images = np.clip(images*0.6, 0.0, 1.0)    # Decreased brightness by a factor of 0.6 & clip any values outside the range of [-1,1]
    altered_brightness_images.extend(inc_brightness_images)
    altered_brightness_images.extend(dec_brightness_images)
    return altered_brightness_images, np.concatenate((keypoints, keypoints))

if config.brightness_augmentation:
    altered_brightness_train_images, altered_brightness_train_keypoints = alter_brightness(clean_train_images, clean_train_keypoints)
    print("Shape of altered_brightness_train_images:", np.shape(altered_brightness_train_images))
    print("Shape of altered_brightness_train_keypoints:", np.shape(altered_brightness_train_keypoints))
    train_images = np.concatenate((train_images, altered_brightness_train_images))
    train_keypoints = np.concatenate((train_keypoints, altered_brightness_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(altered_brightness_train_images[19], altered_brightness_train_keypoints[19], axis, "Increased Brightness") 
    fig, axis = plt.subplots()
    plot_sample(altered_brightness_train_images[len(altered_brightness_train_images)//2+19], altered_brightness_train_keypoints[len(altered_brightness_train_images)//2+19], axis, "Decreased Brightness")
# Out:
# Shape of altered_brightness_train_images: (166, 128, 128, 1)
# Shape of altered_brightness_train_keypoints: (166, 16)

# %%
def shift_images(images, keypoints):
    shifted_images = []
    shifted_keypoints = []
    for shift in config.pixel_shifts:    # Augmenting over several pixel shift values
        for (shift_x,shift_y) in [(-shift,-shift),(-shift,shift),(shift,-shift),(shift,shift)]:
            M = np.float32([[1,0,shift_x],[0,1,shift_y]])
            for image, keypoint in zip(images, keypoints):
                shifted_image = cv2.warpAffine(image, M, (config.X_RES,config.X_RES), flags=cv2.INTER_CUBIC)
                shifted_keypoint = np.array([(point+shift_x) if idx%2==0 else (point+shift_y) for idx, point in enumerate(keypoint)])
                if np.all(0.0<shifted_keypoint) and np.all(shifted_keypoint<config.X_RES):
                    shifted_images.append(shifted_image.reshape(config.X_RES,config.X_RES,1))
                    shifted_keypoints.append(shifted_keypoint)
    shifted_keypoints = np.clip(shifted_keypoints,0.0,config.X_RES)
    return shifted_images, shifted_keypoints

if config.shift_augmentation:
    shifted_train_images, shifted_train_keypoints = shift_images(clean_train_images, clean_train_keypoints)
    print("Shape of shifted_train_images:", np.shape(shifted_train_images))
    print("Shape of shifted_train_keypoints:", np.shape(shifted_train_keypoints))
    train_images = np.concatenate((train_images, shifted_train_images))
    train_keypoints = np.concatenate((train_keypoints, shifted_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(shifted_train_images[19], shifted_train_keypoints[19], axis, "Shift Augmentation")
# Out:
# Shape of shifted_train_images: (332, 128, 128, 1)
# Shape of shifted_train_keypoints: (332, 16)

# %%
def add_noise(images):
    noisy_images = []
    for image in images:
        noisy_image = cv2.add(image, 0.009*np.random.randn(config.X_RES,config.Y_RES,1))    # Adding random normal noise to the input image & clip the resulting noisy image between [-1,1]
        noisy_images.append(noisy_image.reshape(config.X_RES,config.Y_RES,1))
    return noisy_images

if config.random_noise_augmentation:
    noisy_train_images = add_noise(clean_train_images)
    print("Shape of noisy_train_images:", np.shape(noisy_train_images))
    train_images = np.concatenate((train_images, noisy_train_images))
    train_keypoints = np.concatenate((train_keypoints, clean_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(noisy_train_images[19], clean_train_keypoints[19], axis, "Random Noise Augmentation")
# Out:
# Shape of noisy_train_images: (83, 128, 128, 1)

# %%
# def contour_agmentation(images):
#     contour_images = []
#     for image in images:
#         image = image * 255
#         image = image.astype(np.uint8)
#         _, binary = cv2.threshold(image, 255 // 2, 255, cv2.THRESH_BINARY_INV)
#         contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#         contour_img = cv2.drawContours(image, contours, -1, (0,255,0), 1)
#         contour_images.append(contour_img.reshape(config.X_RES,config.Y_RES,1))
#     return contour_images

# if config.random_noise_augmentation:
#     contour_train_images = contour_agmentation(clean_train_images)
#     print("Shape of countour:", np.shape(contour_train_images))
#     train_images = np.concatenate((train_images, contour_train_images))
#     train_keypoints = np.concatenate((train_keypoints, clean_train_keypoints))
#     fig, axis = plt.subplots()
#     plot_sample(contour_train_images[19], clean_train_keypoints[19], axis, "Contour Augmentation")

# %% [markdown]
# ## Visualize Train images & corresponding Keypoints

# %%
print("Shape of final train_images:", np.shape(train_images))
print("Shape of final train_keypoints:", np.shape(train_keypoints))

print("\nClean Train Data: ")
fig = plt.figure(figsize=(20,8))
for i in range(10):
    axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
    plot_sample(clean_train_images[i], clean_train_keypoints[i], axis, "")
plt.show()

# print("Unclean Train Data: ")
# fig = plt.figure(figsize=(20,8))
# for i in range(10):
#     axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
#     plot_sample(unclean_train_images[i], unclean_train_keypoints[i], axis, "")
# plt.show()

if config.horizontal_flip:
    print("Horizontal Flip Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(flipped_train_images[i], flipped_train_keypoints[i], axis, "")
    plt.show()

if config.rotation_augmentation:
    print("Rotation Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(rotated_train_images[i], rotated_train_keypoints[i], axis, "")
    plt.show()
    
if config.brightness_augmentation:
    print("Brightness Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(altered_brightness_train_images[i], altered_brightness_train_keypoints[i], axis, "")
    plt.show()

if config.shift_augmentation:
    print("Shift Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(shifted_train_images[i], shifted_train_keypoints[i], axis, "")
    plt.show()
    
if config.random_noise_augmentation:
    print("Random Noise Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(noisy_train_images[i], clean_train_keypoints[i], axis, "")
    plt.show()
# Out:
# Shape of final train_images: (913, 128, 128, 1)
# Shape of final train_keypoints: (913, 16)
#
# Clean Train Data:
# Horizontal Flip Augmentation:
# Rotation Augmentation:
# Brightness Augmentation:
# Shift Augmentation:
# Random Noise Augmentation:

# %% [markdown]
# # Model

# %%
print(len(train_images))
# Out:
# 913

# %%
model = keras.Sequential()

pretrained_model = tensorflow.keras.applications.MobileNet(input_shape=(config.X_RES, config.X_RES, 3), include_top=False, weights='imagenet')
pretrained_model.trainable = True

model.add(keras.layers.Convolution2D(3, (1, 1), padding='same', input_shape=(config.X_RES,config.X_RES,1)))
model.add(keras.layers.LeakyReLU(alpha = 0.1))
model.add(pretrained_model)
model.add(keras.layers.GlobalAveragePooling2D())
model.add(keras.layers.Dropout(0.1))
model.add(keras.layers.Dense(16))
model.summary()
# Out:
# 2021-11-04 21:53:31.473932: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-11-04 21:53:31.482557: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-11-04 21:53:31.524660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-04 21:53:31.525163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-11-04 21:53:31.525296: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-11-04 21:53:31.525405: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/llelievr/Documents/Prog/futurabeast/futra-face-tracker/.venv-nix/lib/python3.8/site-packages/cv2/../../lib64:/nix/store/50msfhkz5wbyk8i78pjv3y9lxdrp7dlm-gcc-10.3.0-lib/lib:/nix/store/60y70c7swi78g160rqm9cfbrhl8ax854-libX11-1.7.2/lib:/nix/store/kpff5x8w7kvfsjdb0saac21hk08zc8c7-ncurses-6.2-abi5-compat/lib:/nix/store/n2c41clrmkzd2hbn0axfn021005xsdsp-nvidia-x11-470.63.01-5.10.76/lib:/nix/store/c35w5n0prvq4v4priyi8fiiq361pmyvp-libGL-1.3.3/lib:/nix/store/n956wvasz9jb3dqrp17xmmfmgkyh6h7g-libzip-1.7.3/lib:/nix/store/a4l1kcvgicllc0k6lp5salmk2nx2gwxa-glib-2.68.4/lib:/nix/store/byjgx101dbj5w0lhbhv04hwx3n7ahw41-cudatoolkit-11.2.1-lib/lib:/nix/store/ch7awcznm3yf972m71in4xsqb32375af-cudatoolkit-11.2-cudnn-8.1.1/lib:/home/llelievr/.nix-profile/lib
# 2021-11-04 21:53:31.525508: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/llelievr/Documents/Prog/futurabeast/futra-face-tracker/.venv-nix/lib/python3.8/site-packages/cv2/../../lib64:/nix/store/50msfhkz5wbyk8i78pjv3y9lxdrp7dlm-gcc-10.3.0-lib/lib:/nix/store/60y70c7swi78g160rqm9cfbrhl8ax854-libX11-1.7.2/lib:/nix/store/kpff5x8w7kvfsjdb0saac21hk08zc8c7-ncurses-6.2-abi5-compat/lib:/nix/store/n2c41clrmkzd2hbn0axfn021005xsdsp-nvidia-x11-470.63.01-5.10.76/lib:/nix/store/c35w5n0prvq4v4priyi8fiiq361pmyvp-libGL-1.3.3/lib:/nix/store/n956wvasz9jb3dqrp17xmmfmgkyh6h7g-libzip-1.7.3/lib:/nix/store/a4l1kcvgicllc0k6lp5salmk2nx2gwxa-glib-2.68.4/lib:/nix/store/byjgx101dbj5w0lhbhv04hwx3n7ahw41-cudatoolkit-11.2.1-lib/lib:/nix/store/ch7awcznm3yf972m71in4xsqb32375af-cudatoolkit-11.2-cudnn-8.1.1/lib:/home/llelievr/.nix-profile/lib
# 2021-11-04 21:53:31.525583: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/llelievr/Documents/Prog/futurabeast/futra-face-tracker/.venv-nix/lib/python3.8/site-packages/cv2/../../lib64:/nix/store/50msfhkz5wbyk8i78pjv3y9lxdrp7dlm-gcc-10.3.0-lib/lib:/nix/store/60y70c7swi78g160rqm9cfbrhl8ax854-libX11-1.7.2/lib:/nix/store/kpff5x8w7kvfsjdb0saac21hk08zc8c7-ncurses-6.2-abi5-compat/lib:/nix/store/n2c41clrmkzd2hbn0axfn021005xsdsp-nvidia-x11-470.63.01-5.10.76/lib:/nix/store/c35w5n0prvq4v4priyi8fiiq361pmyvp-libGL-1.3.3/lib:/nix/store/n956wvasz9jb3dqrp17xmmfmgkyh6h7g-libzip-1.7.3/lib:/nix/store/a4l1kcvgicllc0k6lp5salmk2nx2gwxa-glib-2.68.4/lib:/nix/store/byjgx101dbj5w0lhbhv04hwx3n7ahw41-cudatoolkit-11.2.1-lib/lib:/nix/store/ch7awcznm3yf972m71in4xsqb32375af-cudatoolkit-11.2-cudnn-8.1.1/lib:/home/llelievr/.nix-profile/lib
# 2021-11-04 21:53:31.525690: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/llelievr/Documents/Prog/futurabeast/futra-face-tracker/.venv-nix/lib/python3.8/site-packages/cv2/../../lib64:/nix/store/50msfhkz5wbyk8i78pjv3y9lxdrp7dlm-gcc-10.3.0-lib/lib:/nix/store/60y70c7swi78g160rqm9cfbrhl8ax854-libX11-1.7.2/lib:/nix/store/kpff5x8w7kvfsjdb0saac21hk08zc8c7-ncurses-6.2-abi5-compat/lib:/nix/store/n2c41clrmkzd2hbn0axfn021005xsdsp-nvidia-x11-470.63.01-5.10.76/lib:/nix/store/c35w5n0prvq4v4priyi8fiiq361pmyvp-libGL-1.3.3/lib:/nix/store/n956wvasz9jb3dqrp17xmmfmgkyh6h7g-libzip-1.7.3/lib:/nix/store/a4l1kcvgicllc0k6lp5salmk2nx2gwxa-glib-2.68.4/lib:/nix/store/byjgx101dbj5w0lhbhv04hwx3n7ahw41-cudatoolkit-11.2.1-lib/lib:/nix/store/ch7awcznm3yf972m71in4xsqb32375af-cudatoolkit-11.2-cudnn-8.1.1/lib:/home/llelievr/.nix-profile/lib
# 2021-11-04 21:53:31.525823: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/llelievr/Documents/Prog/futurabeast/futra-face-tracker/.venv-nix/lib/python3.8/site-packages/cv2/../../lib64:/nix/store/50msfhkz5wbyk8i78pjv3y9lxdrp7dlm-gcc-10.3.0-lib/lib:/nix/store/60y70c7swi78g160rqm9cfbrhl8ax854-libX11-1.7.2/lib:/nix/store/kpff5x8w7kvfsjdb0saac21hk08zc8c7-ncurses-6.2-abi5-compat/lib:/nix/store/n2c41clrmkzd2hbn0axfn021005xsdsp-nvidia-x11-470.63.01-5.10.76/lib:/nix/store/c35w5n0prvq4v4priyi8fiiq361pmyvp-libGL-1.3.3/lib:/nix/store/n956wvasz9jb3dqrp17xmmfmgkyh6h7g-libzip-1.7.3/lib:/nix/store/a4l1kcvgicllc0k6lp5salmk2nx2gwxa-glib-2.68.4/lib:/nix/store/byjgx101dbj5w0lhbhv04hwx3n7ahw41-cudatoolkit-11.2.1-lib/lib:/nix/store/ch7awcznm3yf972m71in4xsqb32375af-cudatoolkit-11.2-cudnn-8.1.1/lib:/home/llelievr/.nix-profile/lib
# 2021-11-04 21:53:31.525948: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/llelievr/Documents/Prog/futurabeast/futra-face-tracker/.venv-nix/lib/python3.8/site-packages/cv2/../../lib64:/nix/store/50msfhkz5wbyk8i78pjv3y9lxdrp7dlm-gcc-10.3.0-lib/lib:/nix/store/60y70c7swi78g160rqm9cfbrhl8ax854-libX11-1.7.2/lib:/nix/store/kpff5x8w7kvfsjdb0saac21hk08zc8c7-ncurses-6.2-abi5-compat/lib:/nix/store/n2c41clrmkzd2hbn0axfn021005xsdsp-nvidia-x11-470.63.01-5.10.76/lib:/nix/store/c35w5n0prvq4v4priyi8fiiq361pmyvp-libGL-1.3.3/lib:/nix/store/n956wvasz9jb3dqrp17xmmfmgkyh6h7g-libzip-1.7.3/lib:/nix/store/a4l1kcvgicllc0k6lp5salmk2nx2gwxa-glib-2.68.4/lib:/nix/store/byjgx101dbj5w0lhbhv04hwx3n7ahw41-cudatoolkit-11.2.1-lib/lib:/nix/store/ch7awcznm3yf972m71in4xsqb32375af-cudatoolkit-11.2-cudnn-8.1.1/lib:/home/llelievr/.nix-profile/lib
# 2021-11-04 21:53:31.527341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-11-04 21:53:31.527389: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-04 21:53:31.527787: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-04 21:53:31.529193: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-11-04 21:53:31.529233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-04 21:53:31.529240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 3)       6
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128, 128, 3)       0
# _________________________________________________________________
# mobilenet_1.00_128 (Function (None, 4, 4, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                16400
# =================================================================
# Total params: 3,245,270
# Trainable params: 3,223,382
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
tensorflow.keras.utils.plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %% [markdown]
# ## Training the model

# %%
# es = callbacks.EarlyStopping(
#     monitor='loss', patience=30, verbose=1, mode='min', baseline=None, restore_best_weights=True
# )

# rlp = callbacks.ReduceLROnPlateau(
#     monitor='val_loss', factor=0.5, patience=5, min_lr=1e-15, mode='min', verbose=1
# )

# model.compile(
#     optimizer='adam', loss='mean_squared_error', metrics=['mae', 'acc']
# )

# history = model.fit(
#     train_images, train_keypoints, epochs=int(1.5*config.NUM_EPOCHS), batch_size=config.BATCH_SIZE, 
#     validation_split=0.05, callbacks=[es, rlp]
# )



es = keras.callbacks.EarlyStopping(
    monitor='loss', patience=30, verbose=1, mode='min', baseline=None, restore_best_weights=True
)

rlp = keras.callbacks.ReduceLROnPlateau(
    monitor='loss', factor=0.5, patience=5, min_lr=1e-15, mode='min', verbose=1
)


model.compile(
    optimizer="adam", loss='mean_squared_error', metrics=['mae', 'acc']
)

history = model.fit(
    train_images, train_keypoints, epochs=2*config.NUM_EPOCHS, batch_size=config.BATCH_SIZE, callbacks=[es, rlp]
)

model.save('saved_model')
# Out:
# Epoch 1/240
# 2021-11-04 21:53:32.733154: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-11-04 21:53:32.751852: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2799925000 Hz
# 15/15 [==============================] - 20s 1s/step - loss: 3395.9986 - mae: 56.4353 - acc: 0.2413
# Epoch 2/240
# 15/15 [==============================] - 17s 1s/step - loss: 1706.3702 - mae: 39.1574 - acc: 0.7009
# Epoch 3/240
# 15/15 [==============================] - 19s 1s/step - loss: 549.9487 - mae: 20.0525 - acc: 0.7878
# Epoch 4/240
# 15/15 [==============================] - 17s 1s/step - loss: 153.3412 - mae: 9.4278 - acc: 0.9148
# Epoch 5/240
# 15/15 [==============================] - 17s 1s/step - loss: 60.4483 - mae: 5.9763 - acc: 0.9478
# Epoch 6/240
# 15/15 [==============================] - 17s 1s/step - loss: 35.3705 - mae: 4.6174 - acc: 0.9576
# Epoch 7/240
# 15/15 [==============================] - 17s 1s/step - loss: 29.0907 - mae: 4.1620 - acc: 0.9537
# Epoch 8/240
# 15/15 [==============================] - 17s 1s/step - loss: 24.6729 - mae: 3.8570 - acc: 0.9584
# Epoch 9/240
# 15/15 [==============================] - 17s 1s/step - loss: 24.5092 - mae: 3.9265 - acc: 0.9600
# Epoch 10/240
# 15/15 [==============================] - 17s 1s/step - loss: 18.5512 - mae: 3.3336 - acc: 0.9738
# Epoch 11/240
# 15/15 [==============================] - 17s 1s/step - loss: 15.9491 - mae: 3.1009 - acc: 0.9727
# Epoch 12/240
# 15/15 [==============================] - 18s 1s/step - loss: 12.9863 - mae: 2.7465 - acc: 0.9745
# Epoch 13/240
# 15/15 [==============================] - 17s 1s/step - loss: 15.2277 - mae: 2.9923 - acc: 0.9743
# Epoch 14/240
# 15/15 [==============================] - 17s 1s/step - loss: 12.2053 - mae: 2.7019 - acc: 0.9720
# Epoch 15/240
# 15/15 [==============================] - 17s 1s/step - loss: 11.5449 - mae: 2.6180 - acc: 0.9679
# Epoch 16/240
# 15/15 [==============================] - 17s 1s/step - loss: 9.4726 - mae: 2.3758 - acc: 0.9754
# Epoch 17/240
# 15/15 [==============================] - 17s 1s/step - loss: 8.9363 - mae: 2.2787 - acc: 0.9869
# Epoch 18/240
# 15/15 [==============================] - 17s 1s/step - loss: 8.4460 - mae: 2.2402 - acc: 0.9831
# Epoch 19/240
# 15/15 [==============================] - 19s 1s/step - loss: 7.4336 - mae: 2.0834 - acc: 0.9797
# Epoch 20/240
# 15/15 [==============================] - 19s 1s/step - loss: 8.1935 - mae: 2.2251 - acc: 0.9865
# Epoch 21/240
# 15/15 [==============================] - 21s 1s/step - loss: 8.6023 - mae: 2.2413 - acc: 0.9834
# Epoch 22/240
# 15/15 [==============================] - 20s 1s/step - loss: 7.7024 - mae: 2.1399 - acc: 0.9743
# Epoch 23/240
# 15/15 [==============================] - 19s 1s/step - loss: 6.6819 - mae: 1.9863 - acc: 0.9773
# Epoch 24/240
# 15/15 [==============================] - 17s 1s/step - loss: 6.0247 - mae: 1.9074 - acc: 0.9742
# Epoch 25/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.7026 - mae: 1.8673 - acc: 0.9827
# Epoch 26/240
# 15/15 [==============================] - 17s 1s/step - loss: 6.1824 - mae: 1.9210 - acc: 0.9778
# Epoch 27/240
# 15/15 [==============================] - 17s 1s/step - loss: 7.2904 - mae: 2.0801 - acc: 0.9750
# Epoch 28/240
# 15/15 [==============================] - 17s 1s/step - loss: 6.6672 - mae: 2.0150 - acc: 0.9779
# Epoch 29/240
# 15/15 [==============================] - 17s 1s/step - loss: 6.5283 - mae: 2.0023 - acc: 0.9759
# Epoch 30/240
# 15/15 [==============================] - 17s 1s/step - loss: 6.1698 - mae: 1.9376 - acc: 0.9813
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 31/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.9149 - mae: 1.8944 - acc: 0.9768
# Epoch 32/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.3048 - mae: 1.7871 - acc: 0.9728
# Epoch 33/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.0250 - mae: 1.7202 - acc: 0.9809
# Epoch 34/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.1457 - mae: 1.7543 - acc: 0.9871
# Epoch 35/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.8511 - mae: 1.7077 - acc: 0.9868
# Epoch 36/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.9067 - mae: 1.8549 - acc: 0.9831
# Epoch 37/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.3153 - mae: 1.7813 - acc: 0.9821
# Epoch 38/240
# 15/15 [==============================] - 17s 1s/step - loss: 5.0256 - mae: 1.7260 - acc: 0.9833
# Epoch 39/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.0254 - mae: 1.5388 - acc: 0.9765
# Epoch 40/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.8345 - mae: 1.5128 - acc: 0.9890
# Epoch 41/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.2306 - mae: 1.6103 - acc: 0.9795
# Epoch 42/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.3104 - mae: 1.6117 - acc: 0.9828
# Epoch 43/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.2699 - mae: 1.5989 - acc: 0.9749
# Epoch 44/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.1036 - mae: 1.5727 - acc: 0.9771
# Epoch 45/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.3532 - mae: 1.6296 - acc: 0.9746
# Epoch 46/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.1120 - mae: 1.5516 - acc: 0.9799
# Epoch 47/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.9505 - mae: 1.5324 - acc: 0.9740
# Epoch 48/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.1395 - mae: 1.5742 - acc: 0.9779
# Epoch 49/240
# 15/15 [==============================] - 18s 1s/step - loss: 4.0980 - mae: 1.5844 - acc: 0.9754
# Epoch 50/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.9974 - mae: 1.5506 - acc: 0.9759
# Epoch 51/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.1078 - mae: 1.5744 - acc: 0.9752
# Epoch 52/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.9917 - mae: 1.5567 - acc: 0.9863
# Epoch 53/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.8380 - mae: 1.5188 - acc: 0.9819
# Epoch 54/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.6033 - mae: 1.4760 - acc: 0.9782
# Epoch 55/240
# 15/15 [==============================] - 17s 1s/step - loss: 4.1683 - mae: 1.5848 - acc: 0.9854
# Epoch 56/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.7346 - mae: 1.4952 - acc: 0.9853
# Epoch 57/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.5802 - mae: 1.4655 - acc: 0.9786
# Epoch 58/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.5095 - mae: 1.4541 - acc: 0.9871
# Epoch 59/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.2142 - mae: 1.3875 - acc: 0.9865
# Epoch 60/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.7629 - mae: 1.5141 - acc: 0.9757
# Epoch 61/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.3202 - mae: 1.4150 - acc: 0.9862
# Epoch 62/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.4853 - mae: 1.4557 - acc: 0.9803
# Epoch 63/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.5658 - mae: 1.4705 - acc: 0.9767
# Epoch 64/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.6760 - mae: 1.4817 - acc: 0.9746
# Epoch 65/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.0129 - mae: 1.3512 - acc: 0.9908
# Epoch 66/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.3850 - mae: 1.4274 - acc: 0.9794
# Epoch 67/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.4135 - mae: 1.4182 - acc: 0.9689
# Epoch 68/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.6491 - mae: 1.4847 - acc: 0.9839
# Epoch 69/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.3964 - mae: 1.3975 - acc: 0.9782
# Epoch 70/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.8953 - mae: 1.5044 - acc: 0.9772
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 71/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.1342 - mae: 1.3810 - acc: 0.9802
# Epoch 72/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.7448 - mae: 1.4972 - acc: 0.9702
# Epoch 73/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.1114 - mae: 1.3742 - acc: 0.9798
# Epoch 74/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.1796 - mae: 1.3910 - acc: 0.9845
# Epoch 75/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.7502 - mae: 1.2753 - acc: 0.9810
# Epoch 76/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.8924 - mae: 1.3285 - acc: 0.9718
# Epoch 77/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.8515 - mae: 1.3202 - acc: 0.9858
# Epoch 78/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.8882 - mae: 1.3243 - acc: 0.9836
# Epoch 79/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6665 - mae: 1.2534 - acc: 0.9799
# Epoch 80/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6195 - mae: 1.2543 - acc: 0.9890
# Epoch 81/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.9554 - mae: 1.3342 - acc: 0.9882
# Epoch 82/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.9724 - mae: 1.3507 - acc: 0.9830
# Epoch 83/240
# 15/15 [==============================] - 17s 1s/step - loss: 3.3111 - mae: 1.3885 - acc: 0.9868
# Epoch 84/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5650 - mae: 1.2479 - acc: 0.9809
# Epoch 85/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5541 - mae: 1.2352 - acc: 0.9918
# Epoch 86/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4680 - mae: 1.2255 - acc: 0.9779
# Epoch 87/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6839 - mae: 1.2738 - acc: 0.9866
# Epoch 88/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.8245 - mae: 1.2930 - acc: 0.9782
# Epoch 89/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.8960 - mae: 1.3215 - acc: 0.9758
# Epoch 90/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.9191 - mae: 1.3327 - acc: 0.9870
# Epoch 91/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6352 - mae: 1.2618 - acc: 0.9875
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 92/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6889 - mae: 1.2847 - acc: 0.9830
# Epoch 93/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5048 - mae: 1.2279 - acc: 0.9859
# Epoch 94/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.8503 - mae: 1.2915 - acc: 0.9782
# Epoch 95/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.7552 - mae: 1.2919 - acc: 0.9732
# Epoch 96/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4732 - mae: 1.2279 - acc: 0.9883
# Epoch 97/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6653 - mae: 1.2783 - acc: 0.9878
# Epoch 98/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4724 - mae: 1.2157 - acc: 0.9818
# Epoch 99/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4120 - mae: 1.2080 - acc: 0.9846
# Epoch 100/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2888 - mae: 1.1792 - acc: 0.9750
# Epoch 101/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2529 - mae: 1.1595 - acc: 0.9820
# Epoch 102/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5635 - mae: 1.2396 - acc: 0.9846
# Epoch 103/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3502 - mae: 1.1967 - acc: 0.9852
# Epoch 104/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3924 - mae: 1.2010 - acc: 0.9802
# Epoch 105/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5266 - mae: 1.2429 - acc: 0.9829
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 106/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5353 - mae: 1.2466 - acc: 0.9797
# Epoch 107/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5516 - mae: 1.2484 - acc: 0.9890
# Epoch 108/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2101 - mae: 1.1586 - acc: 0.9798
# Epoch 109/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6482 - mae: 1.2662 - acc: 0.9723
# Epoch 110/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3985 - mae: 1.2040 - acc: 0.9832
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 111/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4276 - mae: 1.2061 - acc: 0.9808
# Epoch 112/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4776 - mae: 1.2216 - acc: 0.9883
# Epoch 113/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2936 - mae: 1.1778 - acc: 0.9906
# Epoch 114/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3640 - mae: 1.1990 - acc: 0.9883
# Epoch 115/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4091 - mae: 1.2152 - acc: 0.9910
# Epoch 116/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3380 - mae: 1.1876 - acc: 0.9757
# Epoch 117/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5153 - mae: 1.2299 - acc: 0.9859
# Epoch 118/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5353 - mae: 1.2484 - acc: 0.9799
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 119/240
# 15/15 [==============================] - 18s 1s/step - loss: 2.1959 - mae: 1.1419 - acc: 0.9872
# Epoch 120/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6837 - mae: 1.2625 - acc: 0.9793
# Epoch 121/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3292 - mae: 1.1859 - acc: 0.9817
# Epoch 122/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3457 - mae: 1.1800 - acc: 0.9855
# Epoch 123/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1646 - mae: 1.1404 - acc: 0.9866
# Epoch 124/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1006 - mae: 1.1227 - acc: 0.9826
# Epoch 125/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3077 - mae: 1.1874 - acc: 0.9809
# Epoch 126/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1330 - mae: 1.1375 - acc: 0.9800
# Epoch 127/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2493 - mae: 1.1606 - acc: 0.9790
# Epoch 128/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.0281 - mae: 1.1109 - acc: 0.9936
# Epoch 129/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4327 - mae: 1.2242 - acc: 0.9807
# Epoch 130/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1029 - mae: 1.1307 - acc: 0.9901
# Epoch 131/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3789 - mae: 1.2017 - acc: 0.9904
# Epoch 132/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4240 - mae: 1.2104 - acc: 0.9812
# Epoch 133/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3279 - mae: 1.1853 - acc: 0.9819
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 134/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3512 - mae: 1.1866 - acc: 0.9809
# Epoch 135/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1349 - mae: 1.1352 - acc: 0.9870
# Epoch 136/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2936 - mae: 1.1730 - acc: 0.9863
# Epoch 137/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3400 - mae: 1.1886 - acc: 0.9861
# Epoch 138/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2248 - mae: 1.1648 - acc: 0.9791
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 139/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2743 - mae: 1.1771 - acc: 0.9860
# Epoch 140/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2852 - mae: 1.1815 - acc: 0.9933
# Epoch 141/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1312 - mae: 1.1358 - acc: 0.9880
# Epoch 142/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.1077 - mae: 1.1199 - acc: 0.9814
# Epoch 143/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5370 - mae: 1.2450 - acc: 0.9841
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 144/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5215 - mae: 1.2411 - acc: 0.9792
# Epoch 145/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5820 - mae: 1.2555 - acc: 0.9825
# Epoch 146/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2400 - mae: 1.1596 - acc: 0.9746
# Epoch 147/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2318 - mae: 1.1614 - acc: 0.9881
# Epoch 148/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2638 - mae: 1.1678 - acc: 0.9741
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 149/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.5176 - mae: 1.2329 - acc: 0.9711
# Epoch 150/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2526 - mae: 1.1764 - acc: 0.9849
# Epoch 151/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.7495 - mae: 1.2732 - acc: 0.9833
# Epoch 152/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6543 - mae: 1.2691 - acc: 0.9868
# Epoch 153/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.6133 - mae: 1.2754 - acc: 0.9863
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 154/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.2364 - mae: 1.1693 - acc: 0.9841
# Epoch 155/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.0753 - mae: 1.1218 - acc: 0.9822
# Epoch 156/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4330 - mae: 1.2161 - acc: 0.9822
# Epoch 157/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.3349 - mae: 1.1982 - acc: 0.9872
# Epoch 158/240
# 15/15 [==============================] - 17s 1s/step - loss: 2.4182 - mae: 1.2145 - acc: 0.9875
# Restoring model weights from the end of the best epoch.
#
# Epoch 00158: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 00158: early stopping
# 2021-11-04 22:38:22.990627: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: saved_model/assets

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(3, 1, figsize=(20, 10))
df = pd.DataFrame(history.history)
df[['mae']].plot(ax=ax[0])
df[['loss']].plot(ax=ax[1])
df[['acc']].plot(ax=ax[2])
ax[0].set_title('Model MAE', fontsize=12)
ax[1].set_title('Model Loss', fontsize=12)
ax[2].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18);

# %% [markdown]
# ## Predicting on Test Set

# %%
# %%time
 
test_preds = model.predict(test_images)
# Out:
# CPU times: user 2.1 s, sys: 25.1 ms, total: 2.13 s
# Wall time: 760 ms

# %% [markdown]
# ## Visualizing Test Predictions

# %%
fig = plt.figure(figsize=(20,16))
for i in range(min(20, len(test_images))):
    axis = fig.add_subplot(4, 5, i+1, xticks=[], yticks=[])
    plot_sample(test_images[i], test_preds[i], axis, "")
