# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import sin, cos, pi
import cv2, os
from tqdm.auto import tqdm

import tensorflow
from keras import layers, callbacks, utils, applications, optimizers
from keras.models import Sequential, Model, load_model

# %%
class config:
    horizontal_flip = True
    rotation_augmentation = True
    brightness_augmentation = True
    shift_augmentation = True
    random_noise_augmentation = True

    rotation_angles = [12]    # Rotation angle in degrees (includes both clockwise & anti-clockwise rotations)
    pixel_shifts = [12]    # Horizontal & vertical shift amount in pixels (includes shift from all 4 corners)

    NUM_EPOCHS = 120
    BATCH_SIZE = 64
    X_RES = 128
    Y_RES = 128

# %% [markdown]
# # Loading Data

# %%
# print("Contents of input/facial-keypoints-detection directory: ")
# !ls ../input/facial-keypoints-detection/

# print("\nExtracting .zip dataset files to working directory ...")
# !unzip -u ../input/facial-keypoints-detection/test.zip
# !unzip -u ../input/facial-keypoints-detection/training.zip

# print("\nCurrent working directory:")
# !pwd
# print("\nContents of working directory:")
# !ls

# %%
# %%time

dataset_folder = './Dataset/'
model_file = dataset_folder + 'model_1634576239418.json'
test_file = dataset_folder + 'model_1634576239418.json'
train_data = pd.read_json(model_file, orient='columns')
test_data = pd.read_json(test_file, orient='columns')
# idlookup_data = pd.read_csv(idlookup_file)
# Out:
# Wall time: 14 ms

# %%
def plot_sample(image, keypoint, axis, title):
    # image = image.reshape(1920, 1080)
    axis.imshow(image, cmap='gray')
    axis.scatter(keypoint[0::2], keypoint[1::2], marker='x', s=20)
    plt.title(title)

# %% [markdown]
# ## Exploring Data

# %%
train_data.head()
# Out:
#                                           image  \
# 0  ezgif-4-2deacb100275-jpg/ezgif-frame-007.jpg
# 1  ezgif-4-2deacb100275-jpg/ezgif-frame-008.jpg
# 2  ezgif-4-2deacb100275-jpg/ezgif-frame-018.jpg
# 3  ezgif-4-2deacb100275-jpg/ezgif-frame-097.jpg
# 4  ezgif-4-2deacb100275-jpg/ezgif-frame-110.jpg
#
#                                               points
# 0  [[58, 51], [45, 52], [57, 60], [64, 61], [70, ...
# 1  [[62, 49], [44, 51], [59, 55], [69, 56], [76, ...
# 2  [[58, 46], [36, 49], [56, 57], [66, 58], [75, ...
# 3  [[58, 45], [40, 48], [55, 57], [66, 58], [75, ...
# 4  [[53, 46], [35, 56], [46, 69], [62, 70], [73, ...

# %%
# test_data.head()

# %%
print("Length of train data:", len(train_data))
# Out:
# Length of train data: 83

# %% [markdown]
# **Find columns having Null values and their counts**

# %%
train_data.isnull().sum()
# Out:
# image     0
# points    0
# dtype: int64

# %% [markdown]
# #### We can observe that approx. 68% of data is missing for several keypoints

# %%
clean_train_data = train_data.dropna()
print("clean_train_data shape:", np.shape(clean_train_data))
# Out:
# clean_train_data shape: (83, 2)

# %%
# %%time



def load_images(image_data):
    images = []
    for index, row in image_data.iterrows():
        img = cv2.imread(dataset_folder + row['image'], cv2.IMREAD_GRAYSCALE) 
        # img = img.astype(np.uint8)
        # gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        img = cv2.resize(img, dsize=(config.X_RES, config.Y_RES))
        # img = img.astype(np.uint8)
        # _, binary = cv2.threshold(img, 255 // 2, 255, cv2.THRESH_BINARY_INV)
        # contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        # blank_image = np.ones((128,128,1), np.uint8)
        # img = cv2.drawContours(blank_image, contours, -1, (255,255,255), 1)
        img = np.reshape(img, (config.X_RES, config.Y_RES,1))
        # image = np.reshape(gray, (1920, 1080, 1))
        images.append(img)
    
    images = np.array(images)/255.
    return images

def load_keypoints(keypoint_data):
    keypoint_features = []

    keys = keypoint_data['points'].apply(lambda i: np.reshape(i, len(i) * 2))
    for idx, sample_keypoints in keys.items():
        keypoint_features.append(sample_keypoints)
    keypoint_features = np.array(keypoint_features, dtype = 'float')
    return keypoint_features

clean_train_images = load_images(clean_train_data)
print("Shape of clean_train_images:", np.shape(clean_train_images))
clean_train_keypoints = load_keypoints(clean_train_data)
print("Shape of clean_train_keypoints:", np.shape(clean_train_keypoints))
test_images = load_images(test_data)
print("Shape of test_images:", np.shape(test_images))

train_images = clean_train_images
train_keypoints = clean_train_keypoints
fig, axis = plt.subplots()
plot_sample(clean_train_images[19], clean_train_keypoints[19], axis, "Sample image & keypoints")
# Out:
# Shape of clean_train_images: (83, 128, 128, 1)
# Shape of clean_train_keypoints: (83, 16)
# Shape of test_images: (83, 128, 128, 1)
# Wall time: 487 ms

# %% [markdown]
# # Augmentation

# %%
def left_right_flip(images, keypoints):
    flipped_keypoints = []
    flipped_images = np.flip(images, axis=2)   # Flip column-wise (axis=2)
    for idx, sample_keypoints in enumerate(keypoints):
        flipped_keypoints.append([config.X_RES-coor if idx%2==0 else coor for idx,coor in enumerate(sample_keypoints)])    # Subtract only X co-ordinates of keypoints from 96 for horizontal flipping
    return flipped_images, flipped_keypoints

if config.horizontal_flip:
    flipped_train_images, flipped_train_keypoints = left_right_flip(clean_train_images, clean_train_keypoints)
    print("Shape of flipped_train_images:", np.shape(flipped_train_images))
    print("Shape of flipped_train_keypoints:", np.shape(flipped_train_keypoints))
    train_images = np.concatenate((train_images, flipped_train_images))
    train_keypoints = np.concatenate((train_keypoints, flipped_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(flipped_train_images[19], flipped_train_keypoints[19], axis, "Horizontally Flipped")
# Out:
# Shape of flipped_train_images: (83, 128, 128, 1)
# Shape of flipped_train_keypoints: (83, 16)

# %%
def rotate_augmentation(images, keypoints):
    rotated_images = []
    rotated_keypoints = []
    print("Augmenting for angles (in degrees): ")
    for angle in config.rotation_angles:    # Rotation augmentation for a list of angle values
        for angle in [angle,-angle]:
            print(f'{angle}', end='  ')
            M = cv2.getRotationMatrix2D((config.X_RES / 2,config.X_RES / 2), angle, 1.0)
            angle_rad = -angle*pi/180.     # Obtain angle in radians from angle in degrees (notice negative sign for change in clockwise vs anti-clockwise directions from conventional rotation to cv2's image rotation)
            # For train_images
            for image in images:
                rotated_image = cv2.warpAffine(image, M, (config.X_RES, config.Y_RES), flags=cv2.INTER_CUBIC)
                rotated_images.append(rotated_image)
            # For train_keypoints
            for keypoint in keypoints:
                rotated_keypoint = keypoint - config.X_RES / 2    # Subtract the middle value of the image dimension
                for idx in range(0,len(rotated_keypoint),2):
                    # https://in.mathworks.com/matlabcentral/answers/93554-how-can-i-rotate-a-set-of-points-in-a-plane-by-a-certain-angle-about-an-arbitrary-point
                    rotated_keypoint[idx] = rotated_keypoint[idx]*cos(angle_rad)-rotated_keypoint[idx+1]*sin(angle_rad)
                    rotated_keypoint[idx+1] = rotated_keypoint[idx]*sin(angle_rad)+rotated_keypoint[idx+1]*cos(angle_rad)
                rotated_keypoint += config.X_RES / 2   # Add the earlier subtracted value
                rotated_keypoints.append(rotated_keypoint)
            
    return np.reshape(rotated_images,(-1,config.X_RES,config.X_RES,1)), rotated_keypoints

print()

if config.rotation_augmentation:
    rotated_train_images, rotated_train_keypoints = rotate_augmentation(clean_train_images, clean_train_keypoints)
    print("Shape of rotated_train_images:", np.shape(rotated_train_images))
    print("Shape of rotated_train_keypoints:", np.shape(rotated_train_keypoints))
    train_images = np.concatenate((train_images, rotated_train_images))
    train_keypoints = np.concatenate((train_keypoints, rotated_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(rotated_train_images[19], rotated_train_keypoints[19], axis, "Rotation Augmentation")
# Out:
# Augmenting for angles (in degrees):
# 12  -12  Shape of rotated_train_images: (166, 128, 128, 1)
# Shape of rotated_train_keypoints: (166, 16)

# %%
def alter_brightness(images, keypoints):
    altered_brightness_images = []
    inc_brightness_images = np.clip(images*1.2, 0.0, 1.0)    # Increased brightness by a factor of 1.2 & clip any values outside the range of [-1,1]
    dec_brightness_images = np.clip(images*0.6, 0.0, 1.0)    # Decreased brightness by a factor of 0.6 & clip any values outside the range of [-1,1]
    altered_brightness_images.extend(inc_brightness_images)
    altered_brightness_images.extend(dec_brightness_images)
    return altered_brightness_images, np.concatenate((keypoints, keypoints))

if config.brightness_augmentation:
    altered_brightness_train_images, altered_brightness_train_keypoints = alter_brightness(clean_train_images, clean_train_keypoints)
    print("Shape of altered_brightness_train_images:", np.shape(altered_brightness_train_images))
    print("Shape of altered_brightness_train_keypoints:", np.shape(altered_brightness_train_keypoints))
    train_images = np.concatenate((train_images, altered_brightness_train_images))
    train_keypoints = np.concatenate((train_keypoints, altered_brightness_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(altered_brightness_train_images[19], altered_brightness_train_keypoints[19], axis, "Increased Brightness") 
    fig, axis = plt.subplots()
    plot_sample(altered_brightness_train_images[len(altered_brightness_train_images)//2+19], altered_brightness_train_keypoints[len(altered_brightness_train_images)//2+19], axis, "Decreased Brightness")
# Out:
# Shape of altered_brightness_train_images: (166, 128, 128, 1)
# Shape of altered_brightness_train_keypoints: (166, 16)

# %%
def shift_images(images, keypoints):
    shifted_images = []
    shifted_keypoints = []
    for shift in config.pixel_shifts:    # Augmenting over several pixel shift values
        for (shift_x,shift_y) in [(-shift,-shift),(-shift,shift),(shift,-shift),(shift,shift)]:
            M = np.float32([[1,0,shift_x],[0,1,shift_y]])
            for image, keypoint in zip(images, keypoints):
                shifted_image = cv2.warpAffine(image, M, (config.X_RES,config.X_RES), flags=cv2.INTER_CUBIC)
                shifted_keypoint = np.array([(point+shift_x) if idx%2==0 else (point+shift_y) for idx, point in enumerate(keypoint)])
                if np.all(0.0<shifted_keypoint) and np.all(shifted_keypoint<config.X_RES):
                    shifted_images.append(shifted_image.reshape(config.X_RES,config.X_RES,1))
                    shifted_keypoints.append(shifted_keypoint)
    shifted_keypoints = np.clip(shifted_keypoints,0.0,config.X_RES)
    return shifted_images, shifted_keypoints

if config.shift_augmentation:
    shifted_train_images, shifted_train_keypoints = shift_images(clean_train_images, clean_train_keypoints)
    print("Shape of shifted_train_images:", np.shape(shifted_train_images))
    print("Shape of shifted_train_keypoints:", np.shape(shifted_train_keypoints))
    train_images = np.concatenate((train_images, shifted_train_images))
    train_keypoints = np.concatenate((train_keypoints, shifted_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(shifted_train_images[19], shifted_train_keypoints[19], axis, "Shift Augmentation")
# Out:
# Shape of shifted_train_images: (332, 128, 128, 1)
# Shape of shifted_train_keypoints: (332, 16)

# %%
def add_noise(images):
    noisy_images = []
    for image in images:
        noisy_image = cv2.add(image, 0.009*np.random.randn(config.X_RES,config.Y_RES,1))    # Adding random normal noise to the input image & clip the resulting noisy image between [-1,1]
        noisy_images.append(noisy_image.reshape(config.X_RES,config.Y_RES,1))
    return noisy_images

if config.random_noise_augmentation:
    noisy_train_images = add_noise(clean_train_images)
    print("Shape of noisy_train_images:", np.shape(noisy_train_images))
    train_images = np.concatenate((train_images, noisy_train_images))
    train_keypoints = np.concatenate((train_keypoints, clean_train_keypoints))
    fig, axis = plt.subplots()
    plot_sample(noisy_train_images[19], clean_train_keypoints[19], axis, "Random Noise Augmentation")
# Out:
# Shape of noisy_train_images: (83, 128, 128, 1)

# %%
# def contour_agmentation(images):
#     contour_images = []
#     for image in images:
#         image = image * 255
#         image = image.astype(np.uint8)
#         _, binary = cv2.threshold(image, 255 // 2, 255, cv2.THRESH_BINARY_INV)
#         contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#         contour_img = cv2.drawContours(image, contours, -1, (0,255,0), 1)
#         contour_images.append(contour_img.reshape(config.X_RES,config.Y_RES,1))
#     return contour_images

# if config.random_noise_augmentation:
#     contour_train_images = contour_agmentation(clean_train_images)
#     print("Shape of countour:", np.shape(contour_train_images))
#     train_images = np.concatenate((train_images, contour_train_images))
#     train_keypoints = np.concatenate((train_keypoints, clean_train_keypoints))
#     fig, axis = plt.subplots()
#     plot_sample(contour_train_images[19], clean_train_keypoints[19], axis, "Contour Augmentation")

# %% [markdown]
# ## Visualize Train images & corresponding Keypoints

# %%
print("Shape of final train_images:", np.shape(train_images))
print("Shape of final train_keypoints:", np.shape(train_keypoints))

print("\nClean Train Data: ")
fig = plt.figure(figsize=(20,8))
for i in range(10):
    axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
    plot_sample(clean_train_images[i], clean_train_keypoints[i], axis, "")
plt.show()

# print("Unclean Train Data: ")
# fig = plt.figure(figsize=(20,8))
# for i in range(10):
#     axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
#     plot_sample(unclean_train_images[i], unclean_train_keypoints[i], axis, "")
# plt.show()

if config.horizontal_flip:
    print("Horizontal Flip Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(flipped_train_images[i], flipped_train_keypoints[i], axis, "")
    plt.show()

if config.rotation_augmentation:
    print("Rotation Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(rotated_train_images[i], rotated_train_keypoints[i], axis, "")
    plt.show()
    
if config.brightness_augmentation:
    print("Brightness Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(altered_brightness_train_images[i], altered_brightness_train_keypoints[i], axis, "")
    plt.show()

if config.shift_augmentation:
    print("Shift Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(shifted_train_images[i], shifted_train_keypoints[i], axis, "")
    plt.show()
    
if config.random_noise_augmentation:
    print("Random Noise Augmentation: ")
    fig = plt.figure(figsize=(20,8))
    for i in range(10):
        axis = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
        plot_sample(noisy_train_images[i], clean_train_keypoints[i], axis, "")
    plt.show()
# Out:
# Shape of final train_images: (913, 128, 128, 1)
# Shape of final train_keypoints: (913, 16)
#
# Clean Train Data:
# Horizontal Flip Augmentation:
# Rotation Augmentation:
# Brightness Augmentation:
# Shift Augmentation:
# Random Noise Augmentation:

# %% [markdown]
# # Model

# %%
print(len(train_images))
# Out:
# 913

# %%
model = Sequential()

pretrained_model = tensorflow.keras.applications.MobileNet(input_shape=(config.X_RES, config.X_RES, 3), include_top=False, weights='imagenet')
pretrained_model.trainable = True

model.add(layers.Convolution2D(3, (1, 1), padding='same', input_shape=(config.X_RES,config.X_RES,1)))
model.add(layers.LeakyReLU(alpha = 0.1))
model.add(pretrained_model)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.1))
model.add(layers.Dense(16))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 3)       6
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128, 128, 3)       0
# _________________________________________________________________
# mobilenet_1.00_128 (Function (None, 4, 4, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                16400
# =================================================================
# Total params: 3,245,270
# Trainable params: 3,223,382
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
tensorflow.keras.utils.plot_model(model, show_shapes=True, expand_nested=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# ## Training the model

# %%
# es = callbacks.EarlyStopping(
#     monitor='loss', patience=30, verbose=1, mode='min', baseline=None, restore_best_weights=True
# )

# rlp = callbacks.ReduceLROnPlateau(
#     monitor='val_loss', factor=0.5, patience=5, min_lr=1e-15, mode='min', verbose=1
# )

# model.compile(
#     optimizer='adam', loss='mean_squared_error', metrics=['mae', 'acc']
# )

# history = model.fit(
#     train_images, train_keypoints, epochs=int(1.5*config.NUM_EPOCHS), batch_size=config.BATCH_SIZE, 
#     validation_split=0.05, callbacks=[es, rlp]
# )



es = callbacks.EarlyStopping(
    monitor='loss', patience=30, verbose=1, mode='min', baseline=None, restore_best_weights=True
)

rlp = callbacks.ReduceLROnPlateau(
    monitor='loss', factor=0.5, patience=5, min_lr=1e-15, mode='min', verbose=1
)


model.compile(
    optimizer="adam", loss='mean_squared_error', metrics=['mae', 'acc']
)

history = model.fit(
    train_images, train_keypoints, epochs=2*config.NUM_EPOCHS, batch_size=config.BATCH_SIZE, callbacks=[es, rlp]
)

model.save('saved_model')
# Out:
# Epoch 1/240
# 15/15 [==============================] - 17s 99ms/step - loss: 3133.9121 - mae: 54.2091 - acc: 0.4447
# Epoch 2/240
# 15/15 [==============================] - 1s 74ms/step - loss: 1524.9446 - mae: 36.7046 - acc: 0.5772
# Epoch 3/240
# 15/15 [==============================] - 1s 70ms/step - loss: 477.0038 - mae: 18.5466 - acc: 0.5696
# Epoch 4/240
# 15/15 [==============================] - 1s 70ms/step - loss: 119.4781 - mae: 8.2488 - acc: 0.8784
# Epoch 5/240
# 15/15 [==============================] - 1s 73ms/step - loss: 53.8520 - mae: 5.6269 - acc: 0.9562
# Epoch 6/240
# 15/15 [==============================] - 1s 70ms/step - loss: 33.3965 - mae: 4.4636 - acc: 0.9562
# Epoch 7/240
# 15/15 [==============================] - 1s 71ms/step - loss: 28.3486 - mae: 4.1218 - acc: 0.9562
# Epoch 8/240
# 15/15 [==============================] - 1s 72ms/step - loss: 23.0560 - mae: 3.7112 - acc: 0.9562
# Epoch 9/240
# 15/15 [==============================] - 1s 70ms/step - loss: 18.2475 - mae: 3.2700 - acc: 0.9573
# Epoch 10/240
# 15/15 [==============================] - 1s 69ms/step - loss: 15.8423 - mae: 3.0511 - acc: 0.9617
# Epoch 11/240
# 15/15 [==============================] - 1s 71ms/step - loss: 13.3376 - mae: 2.7899 - acc: 0.9606
# Epoch 12/240
# 15/15 [==============================] - 1s 70ms/step - loss: 12.9604 - mae: 2.7342 - acc: 0.9628
# Epoch 13/240
# 15/15 [==============================] - 1s 69ms/step - loss: 11.9447 - mae: 2.6473 - acc: 0.9704
# Epoch 14/240
# 15/15 [==============================] - 1s 71ms/step - loss: 10.6810 - mae: 2.4827 - acc: 0.9770
# Epoch 15/240
# 15/15 [==============================] - 1s 72ms/step - loss: 10.0912 - mae: 2.4120 - acc: 0.9770
# Epoch 16/240
# 15/15 [==============================] - 1s 70ms/step - loss: 9.3773 - mae: 2.3579 - acc: 0.9748
# Epoch 17/240
# 15/15 [==============================] - 1s 70ms/step - loss: 9.1417 - mae: 2.3191 - acc: 0.9759
# Epoch 18/240
# 15/15 [==============================] - 1s 68ms/step - loss: 9.8940 - mae: 2.3657 - acc: 0.9770
# Epoch 19/240
# 15/15 [==============================] - 1s 69ms/step - loss: 8.4896 - mae: 2.2358 - acc: 0.9726
# Epoch 20/240
# 15/15 [==============================] - 1s 68ms/step - loss: 7.2692 - mae: 2.0497 - acc: 0.9792
# Epoch 21/240
# 15/15 [==============================] - 1s 69ms/step - loss: 6.9976 - mae: 2.0198 - acc: 0.9726
# Epoch 22/240
# 15/15 [==============================] - 1s 70ms/step - loss: 7.1927 - mae: 2.0537 - acc: 0.9781
# Epoch 23/240
# 15/15 [==============================] - 1s 71ms/step - loss: 6.5189 - mae: 1.9517 - acc: 0.9770
# Epoch 24/240
# 15/15 [==============================] - 1s 69ms/step - loss: 6.3536 - mae: 1.9545 - acc: 0.9814
# Epoch 25/240
# 15/15 [==============================] - 1s 70ms/step - loss: 6.2253 - mae: 1.9206 - acc: 0.9781
# Epoch 26/240
# 15/15 [==============================] - 1s 71ms/step - loss: 5.9669 - mae: 1.8765 - acc: 0.9803
# Epoch 27/240
# 15/15 [==============================] - 1s 71ms/step - loss: 7.2844 - mae: 2.0901 - acc: 0.9803
# Epoch 28/240
# 15/15 [==============================] - 1s 71ms/step - loss: 6.6793 - mae: 2.0109 - acc: 0.9825
# Epoch 29/240
# 15/15 [==============================] - 1s 74ms/step - loss: 5.5473 - mae: 1.8397 - acc: 0.9825
# Epoch 30/240
# 15/15 [==============================] - 1s 71ms/step - loss: 5.3898 - mae: 1.7952 - acc: 0.9825
# Epoch 31/240
# 15/15 [==============================] - 1s 71ms/step - loss: 5.5029 - mae: 1.8163 - acc: 0.9814
# Epoch 32/240
# 15/15 [==============================] - 1s 70ms/step - loss: 4.8352 - mae: 1.7050 - acc: 0.9770
# Epoch 33/240
# 15/15 [==============================] - 1s 70ms/step - loss: 5.0839 - mae: 1.7685 - acc: 0.9770
# Epoch 34/240
# 15/15 [==============================] - 1s 70ms/step - loss: 5.3706 - mae: 1.7906 - acc: 0.9748
# Epoch 35/240
# 15/15 [==============================] - 1s 69ms/step - loss: 5.4672 - mae: 1.8147 - acc: 0.9781
# Epoch 36/240
# 15/15 [==============================] - 1s 71ms/step - loss: 4.7276 - mae: 1.6870 - acc: 0.9814
# Epoch 37/240
# 15/15 [==============================] - 1s 71ms/step - loss: 4.7925 - mae: 1.6990 - acc: 0.9814
# Epoch 38/240
# 15/15 [==============================] - 1s 69ms/step - loss: 4.8220 - mae: 1.7146 - acc: 0.9781
# Epoch 39/240
# 15/15 [==============================] - 1s 69ms/step - loss: 5.2173 - mae: 1.7760 - acc: 0.9726
# Epoch 40/240
# 15/15 [==============================] - 1s 69ms/step - loss: 4.8595 - mae: 1.7220 - acc: 0.9781
# Epoch 41/240
# 15/15 [==============================] - 1s 69ms/step - loss: 4.5536 - mae: 1.6558 - acc: 0.9759
# Epoch 42/240
# 15/15 [==============================] - 1s 69ms/step - loss: 4.6837 - mae: 1.6917 - acc: 0.9803
# Epoch 43/240
# 15/15 [==============================] - 1s 70ms/step - loss: 4.9438 - mae: 1.7055 - acc: 0.9759
# Epoch 44/240
# 15/15 [==============================] - 1s 76ms/step - loss: 3.7295 - mae: 1.5033 - acc: 0.9836
# Epoch 45/240
# 15/15 [==============================] - 1s 75ms/step - loss: 4.0488 - mae: 1.5637 - acc: 0.9759
# Epoch 46/240
# 15/15 [==============================] - 1s 76ms/step - loss: 3.7432 - mae: 1.5043 - acc: 0.9759
# Epoch 47/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.8666 - mae: 1.5359 - acc: 0.9759
# Epoch 48/240
# 15/15 [==============================] - 1s 70ms/step - loss: 4.2931 - mae: 1.6012 - acc: 0.9825
# Epoch 49/240
# 15/15 [==============================] - 1s 69ms/step - loss: 4.1024 - mae: 1.5550 - acc: 0.9825
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 50/240
# 15/15 [==============================] - 1s 71ms/step - loss: 3.6345 - mae: 1.4622 - acc: 0.9715
# Epoch 51/240
# 15/15 [==============================] - 1s 72ms/step - loss: 3.4566 - mae: 1.4337 - acc: 0.9759
# Epoch 52/240
# 15/15 [==============================] - 1s 70ms/step - loss: 3.3757 - mae: 1.4104 - acc: 0.9748
# Epoch 53/240
# 15/15 [==============================] - 1s 72ms/step - loss: 3.3399 - mae: 1.4182 - acc: 0.9814
# Epoch 54/240
# 15/15 [==============================] - 1s 70ms/step - loss: 3.1333 - mae: 1.3525 - acc: 0.9836
# Epoch 55/240
# 15/15 [==============================] - 1s 69ms/step - loss: 3.7971 - mae: 1.4785 - acc: 0.9814
# Epoch 56/240
# 15/15 [==============================] - 1s 73ms/step - loss: 3.3248 - mae: 1.4013 - acc: 0.9836
# Epoch 57/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.4058 - mae: 1.4094 - acc: 0.9869
# Epoch 58/240
# 15/15 [==============================] - 1s 76ms/step - loss: 3.1049 - mae: 1.3605 - acc: 0.9836
# Epoch 59/240
# 15/15 [==============================] - 1s 75ms/step - loss: 3.0750 - mae: 1.3617 - acc: 0.9880
# Epoch 60/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.2780 - mae: 1.3827 - acc: 0.9803
# Epoch 61/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.4658 - mae: 1.4249 - acc: 0.9836
# Epoch 62/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.3660 - mae: 1.3959 - acc: 0.9803
# Epoch 63/240
# 15/15 [==============================] - 1s 78ms/step - loss: 3.0998 - mae: 1.3603 - acc: 0.9869
# Epoch 64/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.5805 - mae: 1.4703 - acc: 0.9704
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 65/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.0163 - mae: 1.3594 - acc: 0.9792
# Epoch 66/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.6613 - mae: 1.2602 - acc: 0.9814
# Epoch 67/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.9662 - mae: 1.3278 - acc: 0.9792
# Epoch 68/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.7480 - mae: 1.2876 - acc: 0.9803
# Epoch 69/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.6357 - mae: 1.2636 - acc: 0.9880
# Epoch 70/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.8858 - mae: 1.3134 - acc: 0.9825
# Epoch 71/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.7594 - mae: 1.2801 - acc: 0.9759
# Epoch 72/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.5737 - mae: 1.2416 - acc: 0.9814
# Epoch 73/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.5823 - mae: 1.2470 - acc: 0.9836
# Epoch 74/240
# 15/15 [==============================] - 1s 73ms/step - loss: 2.7097 - mae: 1.2623 - acc: 0.9792
# Epoch 75/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.8345 - mae: 1.2751 - acc: 0.9803
# Epoch 76/240
# 15/15 [==============================] - 1s 74ms/step - loss: 3.6187 - mae: 1.4467 - acc: 0.9836
# Epoch 77/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.8375 - mae: 1.3062 - acc: 0.9858
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 78/240
# 15/15 [==============================] - 1s 77ms/step - loss: 3.1346 - mae: 1.3700 - acc: 0.9825
# Epoch 79/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.5516 - mae: 1.2392 - acc: 0.9836
# Epoch 80/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.5181 - mae: 1.2280 - acc: 0.9759
# Epoch 81/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.5062 - mae: 1.2159 - acc: 0.9814
# Epoch 82/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.7811 - mae: 1.2871 - acc: 0.9759
# Epoch 83/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.3245 - mae: 1.1687 - acc: 0.9880
# Epoch 84/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3197 - mae: 1.1773 - acc: 0.9814
# Epoch 85/240
# 15/15 [==============================] - 1s 78ms/step - loss: 2.4513 - mae: 1.2057 - acc: 0.9803
# Epoch 86/240
# 15/15 [==============================] - 1s 78ms/step - loss: 2.3399 - mae: 1.1883 - acc: 0.9869
# Epoch 87/240
# 15/15 [==============================] - 1s 76ms/step - loss: 3.3133 - mae: 1.2929 - acc: 0.9792
# Epoch 88/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.7733 - mae: 1.2724 - acc: 0.9825
# Epoch 89/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.4332 - mae: 1.2040 - acc: 0.9847
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 90/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.4491 - mae: 1.2060 - acc: 0.9781
# Epoch 91/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.5133 - mae: 1.2296 - acc: 0.9792
# Epoch 92/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3205 - mae: 1.1733 - acc: 0.9869
# Epoch 93/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.4299 - mae: 1.2125 - acc: 0.9836
# Epoch 94/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.5094 - mae: 1.2372 - acc: 0.9803
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 95/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.3695 - mae: 1.1951 - acc: 0.9836
# Epoch 96/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3134 - mae: 1.1811 - acc: 0.9836
# Epoch 97/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.3197 - mae: 1.1850 - acc: 0.9825
# Epoch 98/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3063 - mae: 1.1682 - acc: 0.9847
# Epoch 99/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.2994 - mae: 1.1640 - acc: 0.9825
# Epoch 100/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.4525 - mae: 1.2215 - acc: 0.9847
# Epoch 101/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.5946 - mae: 1.2583 - acc: 0.9847
# Epoch 102/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.2466 - mae: 1.1613 - acc: 0.9814
# Epoch 103/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.2379 - mae: 1.1583 - acc: 0.9858
# Epoch 104/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.4485 - mae: 1.2029 - acc: 0.9814
# Epoch 105/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.0952 - mae: 1.1162 - acc: 0.9869
# Epoch 106/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.3648 - mae: 1.1962 - acc: 0.9880
# Epoch 107/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.3211 - mae: 1.1748 - acc: 0.9825
# Epoch 108/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3910 - mae: 1.2048 - acc: 0.9847
# Epoch 109/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.2771 - mae: 1.1658 - acc: 0.9803
# Epoch 110/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.1603 - mae: 1.1362 - acc: 0.9836
#
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 111/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.2495 - mae: 1.1637 - acc: 0.9836
# Epoch 112/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3007 - mae: 1.1674 - acc: 0.9781
# Epoch 113/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.3873 - mae: 1.2019 - acc: 0.9836
# Epoch 114/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.2029 - mae: 1.1467 - acc: 0.9792
# Epoch 115/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.1691 - mae: 1.1409 - acc: 0.9836
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 116/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.4230 - mae: 1.2066 - acc: 0.9781
# Epoch 117/240
# 15/15 [==============================] - 1s 72ms/step - loss: 2.3518 - mae: 1.1856 - acc: 0.9847
# Epoch 118/240
# 15/15 [==============================] - 1s 72ms/step - loss: 2.1388 - mae: 1.1363 - acc: 0.9847
# Epoch 119/240
# 15/15 [==============================] - 1s 76ms/step - loss: 2.1227 - mae: 1.1280 - acc: 0.9803
# Epoch 120/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.3980 - mae: 1.1897 - acc: 0.9847
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 121/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.1564 - mae: 1.1346 - acc: 0.9836
# Epoch 122/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.3751 - mae: 1.1873 - acc: 0.9814
# Epoch 123/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.3805 - mae: 1.2012 - acc: 0.9814
# Epoch 124/240
# 15/15 [==============================] - 1s 75ms/step - loss: 2.1739 - mae: 1.1359 - acc: 0.9880
# Epoch 125/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.3341 - mae: 1.1758 - acc: 0.9869
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 126/240
# 15/15 [==============================] - 1s 73ms/step - loss: 2.3102 - mae: 1.1850 - acc: 0.9858
# Epoch 127/240
# 15/15 [==============================] - 1s 73ms/step - loss: 2.2945 - mae: 1.1788 - acc: 0.9792
# Epoch 128/240
# 15/15 [==============================] - 1s 73ms/step - loss: 2.2782 - mae: 1.1734 - acc: 0.9825
# Epoch 129/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.2041 - mae: 1.1436 - acc: 0.9858
# Epoch 130/240
# 15/15 [==============================] - 1s 82ms/step - loss: 2.3051 - mae: 1.1651 - acc: 0.9836
#
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 131/240
# 15/15 [==============================] - 1s 78ms/step - loss: 2.2478 - mae: 1.1536 - acc: 0.9803
# Epoch 132/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.1012 - mae: 1.1297 - acc: 0.9825
# Epoch 133/240
# 15/15 [==============================] - 1s 78ms/step - loss: 2.2421 - mae: 1.1519 - acc: 0.9869
# Epoch 134/240
# 15/15 [==============================] - 1s 77ms/step - loss: 2.2741 - mae: 1.1643 - acc: 0.9803
# Epoch 135/240
# 15/15 [==============================] - 1s 74ms/step - loss: 2.2648 - mae: 1.1611 - acc: 0.9825
# Restoring model weights from the end of the best epoch.
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 00135: early stopping
# INFO:tensorflow:Assets written to: saved_model\assets

# %%
sns.set_style('darkgrid')

fig, ax = plt.subplots(3, 1, figsize=(20, 10))
df = pd.DataFrame(history.history)
df[['mae']].plot(ax=ax[0])
df[['loss']].plot(ax=ax[1])
df[['acc']].plot(ax=ax[2])
ax[0].set_title('Model MAE', fontsize=12)
ax[1].set_title('Model Loss', fontsize=12)
ax[2].set_title('Model Acc', fontsize=12)
fig.suptitle('Model Metrics', fontsize=18);

# %% [markdown]
# ## Predicting on Test Set

# %%
# %%time
 
test_preds = model.predict(test_images)
# Out:
# Wall time: 737 ms

# %% [markdown]
# ## Visualizing Test Predictions

# %%
fig = plt.figure(figsize=(20,16))
for i in range(min(20, len(test_images))):
    axis = fig.add_subplot(4, 5, i+1, xticks=[], yticks=[])
    plot_sample(test_images[i], test_preds[i], axis, "")
